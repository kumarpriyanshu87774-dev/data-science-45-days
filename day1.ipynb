# %%
print("hello world")
a=7
b=8
print(a+b)
# Out:
# hello world
# 15

# %%
#sum of two number
num1=int(input("enter the first number"))
num2=int(input("enter the second number"))
sum=num1+num2
print("sum of two number=",sum)
# Out:
# enter the first number87
# enter the second number89
# sum of two number= 176
