# %%
print("hello world")
a=7
b=8
print(a+b)
# Out:
# hello world
# 15

# %%
#sum of two number
num1=int(input("enter the first number"))
num2=int(input("enter the second number"))
sum=num1+num2
print("sum of two number=",sum)
# Out:
# enter the first number67
# enter the second number87
# sum of two number= 154

# %%
#operator in python
#arithmetic operator
a=8
b=4

print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a**b)
#logical operator
num1=True
num2=False
print(num1 and num2)
print(num1 or num2)
print( not True)
# Out:
# 12
# 4
# 32
# 2.0
# 4096
# False
# True
# False

# %%
#type casting in python
a=98
b=68.8
c=int('2')
print(a+b)
print(a+int(b))
print(a+c)
# Out:
# 166.8
# 166
# 100

# %%
#input in python
#circle of area
radius=float(input("enter the radius"))
area=3.14*radius*radius
print("area of circle is:",area)
# Out:
# enter the radius56
# area of circle is: 9847.04

# %%
#two input number a and b if a is greater than or equal to b print true.if not print false
a=int(input("enter first number"))
b=int(input("enter second number"))
print(a>=b)
# Out:
# enter first number101
# enter second number102
# False
